# %% [markdown]
# This code was written for running neuron population morphology-based clustering

# %% [markdown]
# Let's start by importing some general necessary packages

# %%
import numpy as np

import matplotlib.pyplot as plt

import pandas as pd

# %% [markdown]
# # Dataset access
# First we need to set up the CAVE client and default dataset, as well as SeaTable access and import of info table

# %%
from fafbseg import flywire

flywire.set_default_dataset('wclee_aedes_brain')
# Out:
# Default dataset set to "wclee_aedes_brain".

# %% [markdown]
# Let's load the aedes table and access to the segmentation

# %%
import os # might be necessary for calling token stored in env variable
import seaserpent as ss 

aedes = ss.Table(table='aedes_main', server='https://flytable.mrc-lmb.cam.ac.uk/', auth_token=os.environ['SEATABLE_TOKEN']) # environment variable has to be defined before with access token 
ades = aedes.to_frame()
aedes.head()
# Out:
#                             supervoxel_id             root_id  serial_id  \
# row_id
# d76kgJ7aRSSG8FVDNH4ZWQ  76280889268882312  648518347481404235      13765
# U31NnNtIRySAo2U_QvFpmQ  75226526269985001  648518347509965429      10001
# PpXg8uYIQRSh2gGzA5R3cA  75226526269992020  648518347501126977      10002
# LKO0_NSdQiSLPO25G2RTcw  75648601497466950  648518347488545557      10003
# ElYAergFQuya_RnzVWCo3w  75367126520739993  648518347570434664      10004
#
#                                                              point_xyz side  \
# row_id
# d76kgJ7aRSSG8FVDNH4ZWQ                                33214,12071,4600    R
# U31NnNtIRySAo2U_QvFpmQ       25416.783203125,20689.4375,4378.982421875    R
# PpXg8uYIQRSh2gGzA5R3cA  25449.474609375,20758.744140625,4378.982421875    R
# LKO0_NSdQiSLPO25G2RTcw                 28597.75,19607.583984375,4773.5    L
# ElYAergFQuya_RnzVWCo3w           26120.669921875,19894.88671875,4773.5    R
#
#                        subsubclass      type  group superclass axon_tract  \
# row_id
# d76kgJ7aRSSG8FVDNH4ZWQ        <NA>      <NA>  11758    central       None
# U31NnNtIRySAo2U_QvFpmQ         RG1  G1a_ivPN  10001    central     [mALT]
# PpXg8uYIQRSh2gGzA5R3cA         RG1  G1b_ilPN  10002    central     [mALT]
# LKO0_NSdQiSLPO25G2RTcw         RG1     G1_PN  10001    central     [mALT]
# ElYAergFQuya_RnzVWCo3w          G2    G2_lPN  10004    central     [mALT]
#
#                         ... root_duplicated soma_xyz birthtime nerve  \
# row_id                  ...
# d76kgJ7aRSSG8FVDNH4ZWQ  ...           False     <NA>      <NA>  <NA>
# U31NnNtIRySAo2U_QvFpmQ  ...           False     <NA>      <NA>  <NA>
# PpXg8uYIQRSh2gGzA5R3cA  ...           False     <NA>      <NA>  <NA>
# LKO0_NSdQiSLPO25G2RTcw  ...           False     <NA>      <NA>  <NA>
# ElYAergFQuya_RnzVWCo3w  ...           False     <NA>      <NA>  <NA>
#
#                                          synonyms   flywire_type instance  \
# row_id
# d76kgJ7aRSSG8FVDNH4ZWQ                       <NA>           <NA>     <NA>
# U31NnNtIRySAo2U_QvFpmQ                       <NA>  VP3+VP1l_ivPN     <NA>
# PpXg8uYIQRSh2gGzA5R3cA                       <NA>           <NA>     <NA>
# LKO0_NSdQiSLPO25G2RTcw  Marin 2020: VP3+VP1l ivPN           <NA>     <NA>
# ElYAergFQuya_RnzVWCo3w                       <NA>           <NA>     <NA>
#
#                        receptor     lrcid serial_id_saved
# row_id
# d76kgJ7aRSSG8FVDNH4ZWQ     <NA>      <NA>           13765
# U31NnNtIRySAo2U_QvFpmQ     <NA>  C003:193           10001
# PpXg8uYIQRSh2gGzA5R3cA     <NA>  C003:195           10002
# LKO0_NSdQiSLPO25G2RTcw     <NA>      <NA>           10003
# ElYAergFQuya_RnzVWCo3w     <NA>  C003:244           10004
#
# [5 rows x 28 columns]

# %% [markdown]
# # Data selection
#
# At this point we need to slice our data table to only contain the neurons we want to cluster. The following cells show an example for neurons of the class 'ALPN', as well as some duplicate filtering.

# %% [markdown]
# Start by filtering neurons of a certain class and ensuring that 'status' is not a dupliccate, fragment or tiny

# %%
alpn_index = ~aedes['status'].isin(['duplicate', 'fragment', 'tiny']) and aedes['class'] == 'ALPN' #create a mask for filtering alpns
alpn = aedes[alpn_index]
print("There are " + str(len(alpn)) + " alpns")
# Out:
# There are 606 alpns

# %% [markdown]
# Next, we check for root_id duplicates, in case they weren't annotated as such; and drop one of the copies

# %%
#check for root_id duplicates
root_id_dups = len(alpn.root_id) - len(np.unique(alpn.root_id))
#drop duplicates
alpn.drop_duplicates(subset='root_id', keep='last', inplace=True)
print("Dropped " + str(root_id_dups) + " root_id duplicates")
print("There are now " + str(len(alpn)) + " alpns")
# Out:
# Dropped 32 root_id duplicates
# There are now 574 alpns

# %% [markdown]
# Now we can go ahead and load the neurons. For clustering we need the dotprops of the neurons, so we'll use the 'flywire.get_l2_dotprops()' function to load them and then scale them to $\mu m$ units

# %%
segment_ids = alpn.root_id.to_list()
dps = flywire.get_l2_dotprops(segment_ids)
dps_um = dps * (1/1000)
# Out:
# Fetching L2 IDs:   0%|          | 0/574 [00:00<?, ?it/s]
# Fetching L2 vectors:   0%|          | 0/347245 [00:00<?, ?it/s]
# Creating dotprops:   0%|          | 0/574 [00:00<?, ?it/s]
# Multiplying:   0%|          | 0/574 [00:00<?, ?it/s]

# %% [markdown]
# # Clustering
#
# Next, we will write some code to run the all by all nblast similarity score, followed by the hierarchical clustering of the neurons

# %%
import navis as nv
aba = nv.nblast_allbyall(dps_um) #run all by all nblast 
print(aba)
# Out:
# Preparing:   0%|          | 0/4 [00:00<?, ?it/s]
# NBLASTing:   0%|          | [00:00<?]
# target              648518347570434664  648518347463367710  \
# query
# 648518347570434664            1.000000           -0.348139
# 648518347463367710           -0.021798            1.000000
# 648518347512933291            0.156090           -0.088112
# 648518347601104736            0.341629           -0.306835
# 648518347541871227            0.140271           -0.511814
# ...                                ...                 ...
# 648518347459238683           -0.880968           -0.881408
# 648518347563795886           -0.880734           -0.881840
# 648518347563704238           -0.847406           -0.850984
# 648518347590451068           -0.218435           -0.502865
# 648518347650783979           -0.881184           -0.881017
#
# target              648518347512933291  648518347601104736  \
# query
# 648518347570434664            0.020049            0.295922
# 648518347463367710           -0.086631           -0.172705
# 648518347512933291            1.000000           -0.016205
# 648518347601104736           -0.009846            1.000000
# 648518347541871227           -0.258236            0.020041
# ...                                ...                 ...
# 648518347459238683           -0.881176           -0.881789
# 648518347563795886           -0.881238           -0.880919
# 648518347563704238           -0.861888           -0.845375
# 648518347590451068           -0.334136           -0.352309
# 648518347650783979           -0.880850           -0.881404
#
# target              648518347541871227  648518347510032245  \
# query
# 648518347570434664            0.072269            0.229379
# 648518347463367710           -0.482449           -0.059658
# 648518347512933291           -0.245722           -0.035203
# 648518347601104736           -0.036503            0.040945
# 648518347541871227            1.000000            0.166040
# ...                                ...                 ...
# 648518347459238683           -0.881523           -0.881495
# 648518347563795886           -0.881336           -0.881704
# 648518347563704238           -0.791619           -0.857777
# 648518347590451068           -0.092225           -0.073884
# 648518347650783979           -0.881276           -0.881026
#
# target              648518347430457591  648518347698967378  \
# query
# 648518347570434664           -0.041287           -0.068034
# 648518347463367710           -0.145431           -0.139691
# 648518347512933291           -0.090979           -0.043760
# 648518347601104736           -0.149354           -0.134258
# 648518347541871227           -0.044189           -0.030736
# ...                                ...                 ...
# 648518347459238683           -0.881269           -0.880606
# 648518347563795886           -0.881139           -0.881834
# 648518347563704238           -0.840652           -0.840328
# 648518347590451068           -0.092845           -0.040716
# 648518347650783979           -0.881114           -0.881755
#
# target              648518347606634527  648518347812890618  ...  \
# query                                                       ...
# 648518347570434664           -0.046124           -0.230181  ...
# 648518347463367710           -0.149449           -0.140413  ...
# 648518347512933291           -0.098622           -0.078881  ...
# 648518347601104736           -0.144440           -0.236180  ...
# 648518347541871227            0.005979           -0.445018  ...
# ...                                ...                 ...  ...
# 648518347459238683           -0.881116           -0.881717  ...
# 648518347563795886           -0.881208           -0.881005  ...
# 648518347563704238           -0.836090           -0.842844  ...
# 648518347590451068           -0.020313           -0.312343  ...
# 648518347650783979           -0.881747           -0.881804  ...
#
# target              648518347625603255  648518347622785529  \
# query
# 648518347570434664            0.260022            0.001067
# 648518347463367710            0.467474            0.207999
# 648518347512933291            0.351119            0.180603
# 648518347601104736            0.352098            0.177178
# 648518347541871227            0.004318           -0.212429
# ...                                ...                 ...
# 648518347459238683           -0.165797           -0.880976
# 648518347563795886           -0.398737           -0.881342
# 648518347563704238           -0.141238           -0.791386
# 648518347590451068           -0.426527           -0.668657
# 648518347650783979           -0.304039           -0.880940
#
# target              648518347614833307  648518347543485969  \
# query
# 648518347570434664            0.034490           -0.053539
# 648518347463367710           -0.374042           -0.343727
# 648518347512933291            0.034569           -0.213046
# 648518347601104736            0.043562           -0.000847
# 648518347541871227           -0.078846           -0.162634
# ...                                ...                 ...
# 648518347459238683           -0.881768           -0.880806
# 648518347563795886           -0.635436           -0.881112
# 648518347563704238           -0.467480           -0.878287
# 648518347590451068           -0.449188           -0.456484
# 648518347650783979           -0.737591           -0.881678
#
# target              648518347550067717  648518347459238683  \
# query
# 648518347570434664           -0.280799           -0.881606
# 648518347463367710           -0.387415           -0.880903
# 648518347512933291           -0.078535           -0.881494
# 648518347601104736           -0.236870           -0.880874
# 648518347541871227           -0.495663           -0.881436
# ...                                ...                 ...
# 648518347459238683           -0.880901            1.000000
# 648518347563795886           -0.881701           -0.462203
# 648518347563704238           -0.881418           -0.455609
# 648518347590451068           -0.650015           -0.880941
# 648518347650783979           -0.881490           -0.407657
#
# target              648518347563795886  648518347563704238  \
# query
# 648518347570434664           -0.881938           -0.855500
# 648518347463367710           -0.881386           -0.838294
# 648518347512933291           -0.881685           -0.834706
# 648518347601104736           -0.882058           -0.821097
# 648518347541871227           -0.881211           -0.763822
# ...                                ...                 ...
# 648518347459238683           -0.344418           -0.574658
# 648518347563795886            1.000000           -0.379203
# 648518347563704238           -0.438570            1.000000
# 648518347590451068           -0.881789           -0.830326
# 648518347650783979           -0.053647           -0.198227
#
# target              648518347590451068  648518347650783979
# query
# 648518347570434664           -0.297898           -0.881502
# 648518347463367710           -0.497247           -0.881120
# 648518347512933291           -0.295997           -0.881503
# 648518347601104736           -0.367714           -0.881756
# 648518347541871227           -0.104986           -0.881518
# ...                                ...                 ...
# 648518347459238683           -0.881217           -0.480321
# 648518347563795886           -0.882041           -0.203748
# 648518347563704238           -0.844038           -0.304498
# 648518347590451068            1.000000           -0.880870
# 648518347650783979           -0.881183            1.000000
#
# [574 rows x 574 columns]

# %% [markdown]
# Now we are ready to run the clustering and plot the dendrogram

# %%
from scipy.spatial.distance import squareform
from scipy.cluster.hierarchy import linkage, dendrogram, set_link_color_palette
import matplotlib.colors as mcl
import seaborn as sns

set_link_color_palette([mcl.to_hex(c) for c in sns.color_palette("muted", 10)])

Z = linkage(aba, method="ward")

# Increase figure size and DPI for clarity
fig, ax = plt.subplots(figsize=(30, 15), dpi=150)

dn = dendrogram(
    Z, 
    labels=aba.columns,    # Set labels
    leaf_rotation=90,      # Rotate leaf labels vertically
    leaf_font_size=5,      # Make leaf labels smaller to fit better
    color_threshold=0,     # Disable color threshold or adjust as needed
    ax=ax
)

plt.title("ALPN Hierarchical Clustering Dendrogram")
ax.set(ylabel="Distance")

sns.despine(trim=True, bottom=True)
plt.show()
fig.savefig("ALPN_dendrogram.pdf")

# %% [markdown]
# # Mirroring neurons
#
# Now that we have a general pipeline for clustering our neuron population, we can improve the predictions by mirroring the neurons on one side of the brain so that homologue neurons across hemispheres are clustered toogether.

# %% [markdown]
# The first step to define our transformation is to load the template brain and the dotprops for the left and right side of the brain.

# %%
reference = pd.read_csv('ref.csv')

target = pd.read_csv('tar.csv')

alpnleft = alpn[alpn["side"] == "L"]
alpnright = alpn[alpn["side"] == "R"]

dpsl = flywire.get_l2_dotprops(alpnleft["root_id"])

dpsr = flywire.get_l2_dotprops(alpnright["root_id"])

dpsuml = dpsl * (1/1000)

dpsumr = dpsr * (1/1000)

aedestemplate = nv.transforms.templates.TemplateBrain(
    name="aedes",
    voxelsize=(0.512, 0.512, 0.512),
    boundingbox=[(35.296, 698.848),
                 (58.784, 522.144),
                 (0, 336.896)],
    units="um"
)

registered = nv.transforms.registry.register_templatebrain(aedestemplate)
# Out:
# Fetching L2 IDs:   0%|          | 0/295 [00:00<?, ?it/s]
# Fetching L2 vectors:   0%|          | 0/176312 [00:00<?, ?it/s]
# Creating dotprops:   0%|          | 0/295 [00:00<?, ?it/s]
# Fetching L2 IDs:   0%|          | 0/277 [00:00<?, ?it/s]
# Fetching L2 vectors:   0%|          | 0/169031 [00:00<?, ?it/s]
# Creating dotprops:   0%|          | 0/277 [00:00<?, ?it/s]
# Multiplying:   0%|          | 0/295 [00:00<?, ?it/s]
# Multiplying:   0%|          | 0/277 [00:00<?, ?it/s]

# %% [markdown]
# Now we can move the subset of one side of neurons into symetric space to be mirrored.

# %%
symspacedpsumr = nv.xform(dpsumr, nv.transforms.thinplate.TPStransform(reference, target))
# Out:
# Xforming:   0%|          | 0/277 [00:00<?, ?it/s]

# %% [markdown]
# Then we can mirror the neurons and return them to the original space.

# %%
mirroredn = nv.mirror_brain(symspacedpsumr, template = "aedes")
# Out:
# Mirroring:   0%|          | 0/277 [00:00<?, ?it/s]

# %%
origspace = nv.xform(mirroredn, nv.transforms.thinplate.TPStransform(target, reference))
# Out:
# Xforming:   0%|          | 0/277 [00:00<?, ?it/s]

# %% [markdown]
# Now we can plot the mirrored neurons to see if our mirroring worked

# %%
### just plot 1 to see, write more code to plot all in interactive plot
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10, 8))
ax[0].scatter(dpsumr.points[0][:,0], dpsumr.points[0][:,1], c='purple', s=20)
ax[1].scatter(origspace.points[0][:,0], origspace.points[0][:,1],c='green', s=20)

plt.show()

# %% [markdown]
# # Clustering with mirror registration
#
# Now we can re-run our clustering using the mirrored neurons plus the original set.

# %%
#dps_L_um.set_neuron_attributes([alpn_mirrored[x] for x in range(len(alpn_mirrored))], name='points') dont understand this line

# %%
all_dps = origspace + dpsuml #add left (now mirrored) and right

# %%
aba = nv.nblast_allbyall(all_dps, progress=True) #run all by all nblast 
aba
# Out:
# Preparing:   0%|          | 0/4 [00:00<?, ?it/s]
# NBLASTing:   0%|          | [00:00<?]
# target              648518347570434664  648518347463367710  \
# query
# 648518347570434664            1.000000           -0.274006
# 648518347463367710           -0.009942            1.000000
# 648518347512933291            0.162454           -0.066633
# 648518347541871227            0.159696           -0.463650
# 648518347510032245            0.251211           -0.324595
# ...                                ...                 ...
# 648518347646485851           -0.129926           -0.234713
# 648518347459238683           -0.300273           -0.389875
# 648518347563795886           -0.135958           -0.223514
# 648518347563704238           -0.286991           -0.628934
# 648518347650783979            0.362108           -0.291997
#
# target              648518347512933291  648518347541871227  \
# query
# 648518347570434664            0.034549            0.096150
# 648518347463367710           -0.091556           -0.446684
# 648518347512933291            1.000000           -0.209570
# 648518347541871227           -0.227295            1.000000
# 648518347510032245           -0.046583            0.005146
# ...                                ...                 ...
# 648518347646485851            0.116489           -0.444235
# 648518347459238683            0.016442           -0.646759
# 648518347563795886           -0.205748            0.038048
# 648518347563704238           -0.378852           -0.364042
# 648518347650783979           -0.113371           -0.016320
#
# target              648518347510032245  648518347430457591  \
# query
# 648518347570434664            0.236272           -0.034511
# 648518347463367710           -0.067205           -0.154090
# 648518347512933291           -0.033530           -0.089736
# 648518347541871227            0.167980           -0.038730
# 648518347510032245            1.000000            0.179134
# ...                                ...                 ...
# 648518347646485851           -0.078215           -0.214474
# 648518347459238683           -0.028415           -0.179318
# 648518347563795886           -0.049157           -0.135805
# 648518347563704238           -0.467916           -0.512389
# 648518347650783979            0.171335           -0.124453
#
# target              648518347698967378  648518347606634527  \
# query
# 648518347570434664           -0.060691           -0.034471
# 648518347463367710           -0.150439           -0.155820
# 648518347512933291           -0.044059           -0.096963
# 648518347541871227           -0.027045            0.009095
# 648518347510032245            0.173969            0.183525
# ...                                ...                 ...
# 648518347646485851           -0.156677           -0.181506
# 648518347459238683           -0.070646           -0.143225
# 648518347563795886           -0.133624           -0.108354
# 648518347563704238           -0.506334           -0.497831
# 648518347650783979           -0.136939           -0.138074
#
# target              648518347812890618  648518347700638862  ...  \
# query                                                       ...
# 648518347570434664           -0.208229           -0.134201  ...
# 648518347463367710           -0.150102           -0.060117  ...
# 648518347512933291           -0.074426            0.017645  ...
# 648518347541871227           -0.370758           -0.383647  ...
# 648518347510032245           -0.115367           -0.071138  ...
# ...                                ...                 ...  ...
# 648518347646485851            0.072637           -0.144137  ...
# 648518347459238683            0.221236           -0.044289  ...
# 648518347563795886           -0.171840           -0.229215  ...
# 648518347563704238           -0.589273           -0.588157  ...
# 648518347650783979           -0.285562           -0.151716  ...
#
# target              648518347531475665  648518347546253438  \
# query
# 648518347570434664            0.305212            0.203057
# 648518347463367710            0.026808            0.041241
# 648518347512933291            0.364882            0.347723
# 648518347541871227            0.283701            0.190242
# 648518347510032245            0.269274           -0.038886
# ...                                ...                 ...
# 648518347646485851            0.088576            0.085869
# 648518347459238683            0.005925            0.268076
# 648518347563795886            0.187981            0.195451
# 648518347563704238           -0.209150           -0.163287
# 648518347650783979            0.141111            0.051396
#
# target              648518347585705431  648518347481956548  \
# query
# 648518347570434664           -0.035871            0.036591
# 648518347463367710           -0.026364            0.055152
# 648518347512933291            0.099821            0.317485
# 648518347541871227           -0.367622           -0.142876
# 648518347510032245           -0.211167           -0.200051
# ...                                ...                 ...
# 648518347646485851           -0.045053            0.042364
# 648518347459238683            0.065172           -0.101736
# 648518347563795886           -0.443309           -0.209870
# 648518347563704238           -0.286266           -0.199463
# 648518347650783979            0.029683           -0.089985
#
# target              648518347673779012  648518347646485851  \
# query
# 648518347570434664           -0.053613           -0.037395
# 648518347463367710           -0.331596           -0.316235
# 648518347512933291            0.149139            0.177708
# 648518347541871227           -0.332866           -0.328173
# 648518347510032245           -0.122587           -0.141499
# ...                                ...                 ...
# 648518347646485851            0.733139            1.000000
# 648518347459238683            0.531998            0.504856
# 648518347563795886           -0.462032           -0.487143
# 648518347563704238           -0.386816           -0.381011
# 648518347650783979           -0.181268           -0.168473
#
# target              648518347459238683  648518347563795886  \
# query
# 648518347570434664           -0.346680           -0.153848
# 648518347463367710           -0.411202           -0.356968
# 648518347512933291           -0.036369           -0.119248
# 648518347541871227           -0.486583           -0.111267
# 648518347510032245           -0.243854           -0.139434
# ...                                ...                 ...
# 648518347646485851           -0.055555           -0.409207
# 648518347459238683            1.000000           -0.344418
# 648518347563795886           -0.462203            1.000000
# 648518347563704238           -0.455609           -0.438570
# 648518347650783979           -0.407657           -0.053647
#
# target              648518347563704238  648518347650783979
# query
# 648518347570434664           -0.044356            0.354353
# 648518347463367710           -0.607751           -0.179701
# 648518347512933291           -0.253430           -0.013202
# 648518347541871227           -0.136210            0.135202
# 648518347510032245           -0.314450            0.086087
# ...                                ...                 ...
# 648518347646485851           -0.565812           -0.298366
# 648518347459238683           -0.574658           -0.480321
# 648518347563795886           -0.379203           -0.203748
# 648518347563704238            1.000000           -0.304498
# 648518347650783979           -0.198227            1.000000
#
# [572 rows x 572 columns]

# %%
from scipy.spatial.distance import squareform
from scipy.cluster.hierarchy import linkage, dendrogram, set_link_color_palette
import matplotlib.colors as mcl
import seaborn as sns

set_link_color_palette([mcl.to_hex(c) for c in sns.color_palette("muted", 10)])


Z = linkage(aba, method="ward")

# Increase figure size and DPI for clarity
fig, ax = plt.subplots(figsize=(30, 15), dpi=150)

dn = dendrogram(
    Z, 
    labels=aba.columns,    # Set labels
    leaf_rotation=90,      # Rotate leaf labels vertically
    leaf_font_size=5,      # Make leaf labels smaller to fit better
    color_threshold=5,     # Disable color threshold or adjust as needed
    ax=ax
)

plt.title("ALPN (mirrored) Hierarchical Clustering Dendrogram")
ax.set(ylabel="Distance")

sns.despine(trim=True, bottom=True)
plt.show()
fig.savefig("ALPN_mirrored_dendrogram.pdf")
