# %%
import pymaid
import pandas as pd
import matplotlib.pyplot as plt

# Set catmaid login instance
rm = pymaid.CatmaidInstance('https://neuropil.janelia.org/tracing/fafb/v14',
                           'fly',
                           'superfly',
                           'Token')

rm.max_threads = 10
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# INFO  : Global CATMAID instance set. Caching is ON. (pymaid)

# %% [markdown]
# # 1

# %%
excit = pymaid.find_neurons(annotations='Rclub_1807_Ex')
inhib = pymaid.find_neurons(annotations='Rclub_1807_In')
# Out:
# HBox(children=(IntProgress(value=0, description='Make nrn', max=10, style=ProgressStyle(description_width='ini…
# INFO  : Found 10 neurons matching the search parameters (pymaid)
# INFO  : Cached data used. Use `pymaid.clear_cache()` to clear. (pymaid)
# HBox(children=(IntProgress(value=0, description='Make nrn', max=10, style=ProgressStyle(description_width='ini…
# INFO  : Found 10 neurons matching the search parameters (pymaid)

# %% [markdown]
# # 2

# %%
one = ['r']*len(inhib)
two = ['b']*len(excit)
color= one+two
fig, ax = pymaid.plot2d([excit, inhib], color=color)
# Out:
# HBox(children=(IntProgress(value=0, description='Plot neurons', max=20, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=1, bar_style='info', description='Plt dotprops', max=1, style=ProgressStyle(d…

# %% [markdown]
# # 3

# %% [markdown]
# Didn't really figure this out.

# %%
al = pymaid.get_volume('AL_R')
lh = pymaid.get_volume('LH_R')

al.color = (0,0.7,0,0.15)
lh.color = (0,0.7,0,0.15)
# Out:
# INFO  : Cached data used. Use `pymaid.clear_cache()` to clear. (pymaid)
# INFO  : Cached data used. Use `pymaid.clear_cache()` to clear. (pymaid)

# %%
# Ignore. Part of trials.
mb = pymaid.get_volume('MB_whole_R')
mb_vl = pymaid.get_volume('MB_VL_R') 
slp = pymaid.get_volume('SLP_R')
# Out:
# INFO  : Cached data used. Use `pymaid.clear_cache()` to clear. (pymaid)
# INFO  : Cached data used. Use `pymaid.clear_cache()` to clear. (pymaid)
# INFO  : Cached data used. Use `pymaid.clear_cache()` to clear. (pymaid)
# INFO  : Cached data used. Use `pymaid.clear_cache()` to clear. (pymaid)
# INFO  : Cached data used. Use `pymaid.clear_cache()` to clear. (pymaid)

# %%
fig, ax = pymaid.plot2d([excit, inhib, lh, al], method='3d_complex', color = color)
# Out:
# HBox(children=(IntProgress(value=0, description='Plot neurons', max=20, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=1, bar_style='info', description='Plt dotprops', max=1, style=ProgressStyle(d…

# %% [markdown]
# # 4

# %%
neuron = pymaid.get_neuron(1722886)

# %% [markdown]
# What is this relation column? I am assuming it's the pre/post synapse

# %%
neuron.connectors.head(3)
# Out:
#    treenode_id  connector_id  relation       x       y       z
# 0     32941440      52206583         1  470688  211551   41000
# 1     33021294      41217595         1  483770  218232   48280
# 2      6328444      40474806         0  394213  167755  168520

# %%
fig, ax = pymaid.plot2d(neuron, cn_size =8)
# Out:
# HBox(children=(IntProgress(value=0, description='Plot neurons', max=1, style=ProgressStyle(description_width='…
# HBox(children=(IntProgress(value=1, bar_style='info', description='Plt dotprops', max=1, style=ProgressStyle(d…

# %% [markdown]
# # 5

# %%
pymaid.cut_neuron(neuron, cut_node=['axon', 'dendrite'])
# Out:
# <class 'pymaid.core.CatmaidNeuronList'> of 3 neurons
#                                    neuron_name skeleton_id  n_nodes  \
# 0  mPN mlALT VM5d+DC4+10 LTS 0.86 1532306 ASB     1722886      932
# 1  mPN mlALT VM5d+DC4+10 LTS 0.86 1532306 ASB     1722886     7256
# 2  mPN mlALT VM5d+DC4+10 LTS 0.86 1532306 ASB     1722886     1083
#
#    n_connectors  n_branch_nodes  n_end_nodes  open_ends  cable_length  \
# 0           139              46           50          0    273.008391
# 1           406             284          290          0   1168.700173
# 2             3               3            5          2    322.748904
#
#   review_status   soma
# 0            NA  False
# 1            NA  False
# 2            NA   True

# %%
n1 = pymaid.cut_neuron(neuron, cut_node=['axon', 'dendrite'])
fig, ax =n1.plot2d()
# Out:
# HBox(children=(IntProgress(value=0, description='Plot neurons', max=3, style=ProgressStyle(description_width='…
# HBox(children=(IntProgress(value=1, bar_style='info', description='Plt dotprops', max=1, style=ProgressStyle(d…

# %% [markdown]
# # 6

# %%
n1 = neuron.prune_by_strahler(to_prune=[1], inplace=False)
n2 = neuron.prune_by_strahler(to_prune=[1,2], inplace=False)
n3 = neuron.prune_by_strahler(to_prune=[1,2,3], inplace=False)
n4 = neuron.prune_by_strahler(to_prune=[1,2,3,4], inplace=False)
n5 = neuron.prune_by_strahler(to_prune=[1,2,3,4,5], inplace=False)

fig, ax = pymaid.plot2d([n1, n2, n3, n4, n5])
# Out:
# HBox(children=(IntProgress(value=0, description='Plot neurons', max=5, style=ProgressStyle(description_width='…
# HBox(children=(IntProgress(value=1, bar_style='info', description='Plt dotprops', max=1, style=ProgressStyle(d…

# %%
fig, ax = pymaid.plot3d([n1, n2, n3, n4, n5])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-110-2f181a427838> in <module>
# ----> 1 fig, ax = pymaid.plot3d([n1, n2, n3, n4, n5])
#
# TypeError: 'NoneType' object is not iterable
