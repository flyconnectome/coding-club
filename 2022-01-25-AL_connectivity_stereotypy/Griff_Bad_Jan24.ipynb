# %% [markdown]
# Exercise: AL Connectivity stereotypy

# %%
import pandas as pd
import numpy as np
import seaserpent as ss

import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

import math 

from fafbseg import flywire
import navis
import pickle
from navis import utils
# %env SEATABLE_TOKEN = 59481ea08c6a2ff4f3635ea54199520ce1a0f1dd
# %env SEATABLE_SERVER = https://flytable.mrc-lmb.cam.ac.uk/
# Out:
# env: SEATABLE_TOKEN=59481ea08c6a2ff4f3635ea54199520ce1a0f1dd
# env: SEATABLE_SERVER=https://flytable.mrc-lmb.cam.ac.uk/

# %% [markdown]
# # set up - please don't re-run

# %% [markdown]
# a. Read AL_library/AL_bodies seatable and extract all ALLNs (cell_class) - select only those that have initials in the checked column and don’t have “messy” in the comments column (there shouldn’t be any).

# %%
AL_table_og = ss.Table(table='AL_bodies')
AL_table = AL_table_og.to_frame()
AL_table.reset_index()
# Out:
#        index             root_id checked_by     pos_x    pos_y   pos_z  \
# 0          0  720575940629315958        ASB  120728.0  88360.0  2617.0
# 1          1  720575940605654402       None  157640.0  62296.0   751.0
# 2          2  720575940618166321       None  104232.0  57736.0   991.0
# 3          3  720575940610800882       None  104584.0  59384.0  1119.0
# 4          4  720575940615433558       None  157544.0  61552.0   557.0
# ...      ...                 ...        ...       ...      ...     ...
# 18835  18835  720575940616364545         GB  153261.0  65649.0   301.0
# 18836  18836  720575940619073195         GB  111628.0  57129.0   532.0
# 18837  18837  720575940617220160         GB  110287.0  55394.0   565.0
# 18838  18838  720575940628604727         GB  154725.0  56447.0   247.0
# 18839  18839  720575940624694078         GB  105437.0  59583.0   799.0
#
#               supervoxel             comments cell_class cell_type  ...  \
# 0      78888860116969946  Bilateral\n\n\n\n\n       ALLN      None  ...
# 1      81490785396413563                 None       ALLN      None  ...
# 2      77760898357374019                 None       ALLN      None  ...
# 3      77831404607694577                 None       ALLN      None  ...
# 4      81420347932538686                 None       ALLN      None  ...
# ...                  ...                  ...        ...       ...  ...
# 18835  81139147766640924                 None         RN            ...
# 18836  78323848310719483                 None         RN            ...
# 18837  78182973383386563                 None         RN            ...
# 18838  81279266779589162                 None         RN            ...
# 18839  77901773284693770                 None         RN            ...
#
#       AL_L_pre  AL_L_total    total  total_pre  total_post  AL_pre_frac  \
# 0       7563.0     14441.0  29951.0    16244.0     14100.0     0.988796
# 1      15757.0     29141.0  29141.0    15817.0     13440.0     0.996207
# 2          0.0         0.0  29055.0    15226.0     13961.0     0.994877
# 3          0.0         0.0  28800.0    14459.0     14508.0     0.995781
# 4      17925.0     28506.0  28506.0    18186.0     10704.0     0.985648
# ...        ...         ...      ...        ...         ...          ...
# 18835      NaN         NaN      NaN        NaN         NaN          NaN
# 18836      NaN         NaN      NaN        NaN         NaN          NaN
# 18837      NaN         NaN      NaN        NaN         NaN          NaN
# 18838      NaN         NaN      NaN        NaN         NaN          NaN
# 18839      NaN         NaN      NaN        NaN         NaN          NaN
#
#       AL_post_frac  upn_sparseness  frac_to_upns  root_duplicated
# 0         0.985035        0.618231      0.060889            False
# 1         0.995833        0.558913      0.063464            False
# 2         0.996132        0.589349      0.069976             True
# 3         0.992694        0.592493      0.071538            False
# 4         0.988509        0.556176      0.048424             True
# ...            ...             ...           ...              ...
# 18835          NaN             NaN           NaN            False
# 18836          NaN             NaN           NaN            False
# 18837          NaN             NaN           NaN            False
# 18838          NaN             NaN           NaN            False
# 18839          NaN             NaN           NaN            False
#
# [18840 rows x 31 columns]

# %%
all_ALLNs = AL_table[AL_table.cell_class=='ALLN']
all_ALLNs.shape
# Out:
# (665, 30)

# %%
new_roots = []
for ind in all_ALLNs.index:
    vox = all_ALLNs.loc[ind].supervoxel
    if vox:
        try:
            new_roots.append(flywire.supervoxels_to_roots(vox)[0])
        except:
            try:
                new_roots.append(all_ALLNs.loc[ind].root_id)
            except:
                pass
    elif all_ALLNs.loc[ind].root_id:
        new_roots.append(all_ALLNs.loc[ind].root_id)

# %%
# checked_ALLNs = all_ALLNs.dropna(subset=['checked_by'])
# checked_ALLNs.shape

# %% [markdown]
# b. Find downstream partners of ALLNs.

# %%
all_down_1 = flywire.fetch_connectivity(new_roots[:330], upstream=False, batch_size=10, live_query=True)
# Out:
# Fetching connectivity:   0%|          | 0/33 [00:00<?, ?it/s]
# WARNING:root:201 - "Limited query to 200000 rows

# %%
all_down_2 = flywire.fetch_connectivity(new_roots[330:390], upstream=False, batch_size=10, live_query=True)
# Out:
# Fetching connectivity:   0%|          | 0/6 [00:00<?, ?it/s]

# %%
all_down_3 = flywire.fetch_connectivity(new_roots[390:], upstream=False, batch_size=10, live_query=False)
# Out:
# Fetching connectivity:   0%|          | 0/28 [00:00<?, ?it/s]

# %%
all_down = all_down_1.append(all_down_2).append(all_down_3)

# %%
all_pres = list(set(all_down.pre))

# %%
len(all_pres)
# Out:
# 478

# %%
conns_pick = open('conns', 'wb')
pickle.dump(all_down, conns_pick)
conns_pick.close()

# %% [markdown]
# c. Group ALLNs morphologically.

# %%
dps = flywire.l2_dotprops(all_pres)
# Out:
# Fetching L2 IDs:   0%|          | 0/478 [00:00<?, ?it/s]
# Fetching L2 vectors:   0%|          | 0/527467 [00:00<?, ?it/s]
# Creating dotprops:   0%|          | 0/478 [00:00<?, ?it/s]

# %%
# dps_pick = open('dps','rb')
# #conn_pick = open('conns','rb')
# dps = pickle.load(dps_pick)
# dps_pick.close()

# %%
dps_pick = open('dps','wb')
pickle.dump(dps_um,dps_pick)
dps_pick.close()

# %%
# dps.remove_duplicates(inplace=True, key = "id")

# %%
dps_um = dps / (1000 / 8)
# Out:
# Dividing:   0%|          | 0/478 [00:00<?, ?it/s]

# %%
nbl = navis.nblast_allbyall(dps_um)
nbl
# Out:
# WARNING : NBLAST is optimized for data in microns and it looks like your queries are not in microns. (navis)
# WARNING:navis:NBLAST is optimized for data in microns and it looks like your queries are not in microns.
# WARNING : NBLAST is optimized for data in microns and it looks like your targets are not in microns. (navis)
# WARNING:navis:NBLAST is optimized for data in microns and it looks like your targets are not in microns.
# Preparing:   0%|          | 0/4 [00:00<?, ?it/s]
# NBlasting:   0%|          | 0/239 [00:00<?, ?it/s]
#
#
# NBlasting:   0%|          | 0/239 [00:00<?, ?it/s]
# NBlasting:   0%|          | 0/239 [00:00<?, ?it/s]
#
# NBlasting:   1%|▏         | 3/239 [00:00<00:09, 25.90it/s]
# NBlasting:   1%|▏         | 3/239 [00:00<00:08, 26.86it/s]
#
# NBlasting:   0%|          | 1/239 [00:00<00:30,  7.81it/s]
#
#
# NBlasting:   0%|          | 1/239 [00:00<00:41,  5.80it/s]
#
# NBlasting:   1%|▏         | 3/239 [00:00<00:19, 12.20it/s]
#
#
# NBlasting:   1%|▏         | 3/239 [00:00<00:22, 10.52it/s]
#
# NBlasting:   2%|▏         | 5/239 [00:00<00:16, 14.47it/s]
#
#
# NBlasting:   3%|▎         | 6/239 [00:00<00:23,  9.84it/s]
#
# NBlasting:   3%|▎         | 7/239 [00:00<00:18, 12.79it/s]
# NBlasting:   3%|▎         | 6/239 [00:00<00:24,  9.46it/s]
#
#
# NBlasting:   3%|▎         | 8/239 [00:00<00:19, 11.81it/s]
# NBlasting:   3%|▎         | 8/239 [00:00<00:20, 11.55it/s]
#
# NBlasting:   4%|▍         | 10/239 [00:00<00:20, 11.28it/s]
#
#
# NBlasting:   4%|▍         | 10/239 [00:01<00:30,  7.51it/s]
#
# NBlasting:   5%|▌         | 12/239 [00:01<00:23,  9.63it/s]
# NBlasting:   4%|▍         | 10/239 [00:01<00:33,  6.86it/s]
#
#
# NBlasting:   5%|▌         | 12/239 [00:01<00:27,  8.19it/s]
#
# NBlasting:   6%|▌         | 14/239 [00:01<00:24,  9.04it/s]
# NBlasting:   5%|▌         | 12/239 [00:01<00:29,  7.69it/s]
#
#
# NBlasting:   6%|▌         | 14/239 [00:01<00:26,  8.49it/s]
#
# NBlasting:   6%|▋         | 15/239 [00:01<00:31,  7.06it/s]
#
#
# NBlasting:   6%|▌         | 14/239 [00:01<00:38,  5.89it/s]
#
# NBlasting:   7%|▋         | 16/239 [00:01<00:29,  7.48it/s]
# NBlasting:   6%|▌         | 14/239 [00:01<00:41,  5.45it/s]
#
#
# NBlasting:   7%|▋         | 16/239 [00:02<00:39,  5.63it/s]
# NBlasting:   8%|▊         | 18/239 [00:02<00:26,  8.38it/s]
#
# NBlasting:   9%|▉         | 22/239 [00:02<00:16, 12.97it/s]
# NBlasting:  10%|█         | 24/239 [00:02<00:15, 13.92it/s]
#
#
# NBlasting:   8%|▊         | 18/239 [00:02<00:36,  5.98it/s]
# NBlasting:  10%|▉         | 23/239 [00:02<00:16, 13.14it/s]
#
# NBlasting:  11%|█         | 26/239 [00:02<00:15, 13.43it/s]
#
#
# NBlasting:   8%|▊         | 19/239 [00:02<00:41,  5.29it/s]
# NBlasting:  10%|█         | 25/239 [00:02<00:18, 11.84it/s]
#
# NBlasting:  12%|█▏        | 28/239 [00:02<00:20, 10.51it/s]
#
# NBlasting:  10%|█         | 24/239 [00:02<00:25,  8.51it/s]
#
#
# NBlasting:   9%|▉         | 22/239 [00:02<00:30,  7.10it/s]
# NBlasting:  12%|█▏        | 28/239 [00:02<00:19, 10.95it/s]
#
#
# NBlasting:  13%|█▎        | 30/239 [00:03<00:24,  8.36it/s]
#
# NBlasting:  10%|█         | 25/239 [00:03<00:32,  6.52it/s]
#
# NBlasting:  72%|███████▏  | 172/239 [00:18<00:06, 11.00it/s]
#
#
# NBlasting:  84%|████████▍ | 201/239 [00:18<00:03, 10.03it/s]
# NBlasting:  80%|████████  | 192/239 [00:18<00:04, 10.33it/s]
#
#
# NBlasting:  85%|████████▌ | 204/239 [00:18<00:03, 10.80it/s]
#
# NBlasting:  86%|████████▌ | 206/239 [00:18<00:03, 10.91it/s]
# NBlasting:  81%|████████  | 194/239 [00:18<00:05,  8.76it/s]
#
# NBlasting:  74%|███████▍  | 177/239 [00:18<00:06, 10.13it/s]
#
#
# NBlasting:  70%|██████▉   | 167/239 [00:19<00:09,  7.44it/s]
#
# NBlasting:  75%|███████▍  | 179/239 [00:19<00:05, 11.27it/s]
# NBlasting:  89%|████████▊ | 212/239 [00:19<00:02, 12.59it/s]
#
#
# NBlasting:  90%|████████▉ | 214/239 [00:19<00:01, 12.69it/s]
# NBlasting:  83%|████████▎ | 198/239 [00:19<00:05,  7.52it/s]
#
# NBlasting:  76%|███████▌  | 181/239 [00:19<00:06,  8.42it/s]
#
# NBlasting:  77%|███████▋  | 183/239 [00:19<00:05,  9.51it/s]
# NBlasting:  84%|████████▍ | 201/239 [00:19<00:04,  9.13it/s]
#
# NBlasting:  90%|█████████ | 216/239 [00:19<00:02,  9.56it/s]
#
#
# NBlasting:  92%|█████████▏| 219/239 [00:19<00:01, 12.45it/s]
# NBlasting:  85%|████████▌ | 204/239 [00:19<00:03,  9.98it/s]
#
# NBlasting:  79%|███████▉  | 190/239 [00:19<00:03, 14.04it/s]
#
#
# NBlasting:  74%|███████▍  | 177/239 [00:20<00:06,  9.27it/s]
# NBlasting:  86%|████████▌ | 206/239 [00:20<00:03,  9.96it/s]
#
#
# NBlasting:  93%|█████████▎| 222/239 [00:20<00:01, 11.55it/s]
#
# NBlasting:  94%|█████████▍| 225/239 [00:20<00:01, 12.35it/s]
# NBlasting:  88%|████████▊ | 210/239 [00:20<00:02, 10.74it/s]
#
#
# NBlasting:  96%|█████████▌| 230/239 [00:20<00:00, 16.60it/s]
# NBlasting:  89%|████████▊ | 212/239 [00:20<00:02, 11.63it/s]
#
# NBlasting:  97%|█████████▋| 232/239 [00:20<00:00, 17.08it/s]
#
#
# NBlasting:  77%|███████▋  | 183/239 [00:20<00:06,  8.86it/s]
# NBlasting:  90%|████████▉ | 214/239 [00:20<00:02, 11.73it/s]
#
# NBlasting:  83%|████████▎ | 198/239 [00:20<00:03, 12.16it/s]
#
#
# NBlasting:  78%|███████▊  | 187/239 [00:20<00:04, 12.56it/s]
#
# NBlasting:  84%|████████▎ | 200/239 [00:21<00:03, 10.64it/s]
#
#
# NBlasting:  79%|███████▉  | 190/239 [00:21<00:03, 13.23it/s]
# NBlasting:  98%|█████████▊| 234/239 [00:21<00:00,  9.91it/s]
#
# NBlasting:  85%|████████▍ | 202/239 [00:21<00:03, 11.27it/s]
# NBlasting:  99%|█████████▉| 237/239 [00:21<00:00, 12.39it/s]
#
#
#
#
# NBlasting:  80%|████████  | 192/239 [00:21<00:04, 10.50it/s]
# NBlasting:  93%|█████████▎| 222/239 [00:21<00:01, 10.84it/s]
#
# NBlasting:  87%|████████▋ | 207/239 [00:21<00:02, 11.44it/s]
#
# NBlasting:  88%|████████▊ | 210/239 [00:21<00:02, 14.36it/s]
#
#
# NBlasting:  81%|████████  | 194/239 [00:21<00:05,  8.71it/s]
# NBlasting:  94%|█████████▍| 225/239 [00:21<00:01, 11.67it/s]
#
#
# NBlasting:  82%|████████▏ | 197/239 [00:21<00:03, 11.55it/s]
# NBlasting:  96%|█████████▌| 229/239 [00:21<00:00, 15.89it/s]
#
#
# NBlasting:  83%|████████▎ | 199/239 [00:22<00:03, 12.51it/s]
#
# NBlasting:  89%|████████▊ | 212/239 [00:22<00:02, 11.90it/s]
# NBlasting:  97%|█████████▋| 232/239 [00:22<00:00, 15.97it/s]
#
#
# NBlasting:  84%|████████▍ | 201/239 [00:22<00:03,  9.54it/s]
#
# NBlasting:  90%|████████▉ | 215/239 [00:22<00:02, 10.41it/s]
#
#
# NBlasting:  85%|████████▍ | 203/239 [00:22<00:03, 10.82it/s]
#
# NBlasting:  91%|█████████ | 218/239 [00:22<00:01, 12.30it/s]
#
#
# NBlasting:  86%|████████▌ | 205/239 [00:22<00:02, 12.14it/s]
# NBlasting:  98%|█████████▊| 234/239 [00:22<00:00,  9.46it/s]
# NBlasting:  99%|█████████▉| 237/239 [00:22<00:00, 11.76it/s]
#
#
#
# NBlasting:  87%|████████▋ | 207/239 [00:22<00:03, 10.60it/s]
#
# NBlasting:  92%|█████████▏| 220/239 [00:22<00:01, 10.12it/s]
#
#
#
#
# NBlasting:  93%|█████████▎| 222/239 [00:22<00:01, 11.55it/s]
#
# NBlasting:  94%|█████████▎| 224/239 [00:23<00:01, 10.29it/s]
#
#
# NBlasting:  89%|████████▊ | 212/239 [00:23<00:02, 11.32it/s]
#
#
# NBlasting:  90%|████████▉ | 215/239 [00:23<00:02,  9.98it/s]
#
# NBlasting:  95%|█████████▍| 226/239 [00:23<00:01,  7.87it/s]
#
# NBlasting:  95%|█████████▌| 228/239 [00:23<00:01,  8.55it/s]
#
#
# NBlasting:  91%|█████████ | 218/239 [00:23<00:01, 10.69it/s]
#
#
# NBlasting:  92%|█████████▏| 220/239 [00:24<00:02,  9.13it/s]
#
# NBlasting:  96%|█████████▌| 230/239 [00:24<00:01,  7.39it/s]
#
#
# NBlasting:  93%|█████████▎| 222/239 [00:24<00:01, 10.54it/s]
#
# NBlasting:  97%|█████████▋| 231/239 [00:24<00:01,  6.41it/s]
#
#
# NBlasting:  94%|█████████▎| 224/239 [00:24<00:01,  9.46it/s]
#
# NBlasting:  97%|█████████▋| 232/239 [00:24<00:01,  6.48it/s]
#
# NBlasting:  98%|█████████▊| 235/239 [00:24<00:00,  7.42it/s]
#
#
# NBlasting:  95%|█████████▍| 226/239 [00:24<00:01,  7.33it/s]
#
# NBlasting: 100%|█████████▉| 238/239 [00:25<00:00,  9.98it/s]
#
#
# NBlasting:  95%|█████████▌| 228/239 [00:25<00:01,  8.66it/s]
#
#
#
#
# 720575940623437838           -0.621890           -0.465493
# ...                                ...                 ...
# 720575940636753897           -0.880711           -0.881583
# 720575940611960813           -0.881438           -0.880478
# 720575940619988980           -0.880910           -0.881387
# 720575940628735993           -0.590836           -0.480190
# 720575940629239803           -0.635459           -0.335334
#
#                     720575940613705695  720575940631558113  \
# 720575940624613376           -0.880944           -0.881127
# 720575940625231872           -0.519959           -0.882310
# 720575940606267403           -0.881177           -0.881463
# 720575940621508621           -0.321812           -0.827069
# 720575940623437838           -0.481537           -0.812057
# ...                                ...                 ...
# 720575940636753897           -0.881225           -0.881302
# 720575940611960813           -0.881104           -0.881227
# 720575940619988980           -0.881311           -0.881378
# 720575940628735993           -0.550250           -0.777386
# 720575940629239803           -0.421621           -0.858169
#
#                     720575940611098595  720575940636753897  \
# 720575940624613376           -0.880169           -0.879711
# 720575940625231872           -0.880646           -0.881114
# 720575940606267403           -0.661875           -0.377225
# 720575940621508621           -0.864096           -0.881591
# 720575940623437838           -0.881603           -0.819400
# ...                                ...                 ...
# 720575940636753897           -0.768803            1.000000
# 720575940611960813           -0.644308           -0.265938
# 720575940619988980           -0.583498           -0.316374
# 720575940628735993           -0.806909           -0.784404
# 720575940629239803           -0.873429           -0.881369
#
#                     720575940611960813  720575940619988980  \
# 720575940624613376           -0.880224           -0.882699
# 720575940625231872           -0.881484           -0.880527
# 720575940606267403           -0.864925           -0.787128
# 720575940621508621           -0.882089           -0.881564
# 720575940623437838           -0.870621           -0.881552
# ...                                ...                 ...
# 720575940636753897           -0.814875           -0.720276
# 720575940611960813            1.000000           -0.678064
# 720575940619988980           -0.827857            1.000000
# 720575940628735993           -0.877401           -0.815223
# 720575940629239803           -0.882019           -0.881540
#
#                     720575940628735993  720575940629239803
# 720575940624613376           -0.730524           -0.859609
# 720575940625231872           -0.605662           -0.696538
# 720575940606267403           -0.880871           -0.881513
# 720575940621508621           -0.739310           -0.571351
# 720575940623437838           -0.670510           -0.591690
# ...                                ...                 ...
# 720575940636753897           -0.852101           -0.881617
# 720575940611960813           -0.865395           -0.881960
# 720575940619988980           -0.773464           -0.880837
# 720575940628735993            1.000000           -0.552307
# 720575940629239803           -0.773773            1.000000
#
# [478 rows x 478 columns]

# %%
from scipy.cluster.hierarchy import fcluster, dendrogram, linkage
from scipy.spatial.distance import squareform 
scores = nbl.copy()
# Assuming "scores" are your NBLAST similarity scores
# First: make matrix symmetric
scores = (scores + scores.T.values) / 2

# Then turn similarity into distances 
dists = (scores - 1) * -1

# Turn square- into vector form
vec = squareform(dists)

# Create linkage
Z = linkage(vec, method='ward')

# Plot dendrogram
dn = dendrogram(Z, labels=scores.index.values)

cl = fcluster(Z, t=9, criterion='maxclust')

# %%
dps['clust'] = cl

# %% [markdown]
# d. Assess connectivity stereotypy from ALLNs to downstream partners - Plot normalised synapse count to downstream partners per ALLN morphological group.

# %%
colors = ['blue', 'red', 'green', 'purple', 'yellow', 'orange', 'cyan', 'magenta', 'lime']

# %%
color_match = [colors[x-1] for x in cl]

# %%
col_dict = dict(zip(all_pres, color_match))

# %%
conn_pick = open('conns','rb')
conns = pickle.load(conn_pick)
conn_pick.close()

# %%
conns = conns[conns.weight>3]

# %%
means = conns.groupby(['pre']).mean().weight
stds = conns.groupby(['pre']).sem().weight

# %%
strength = pd.DataFrame(columns=['id', 'avg', 'stds', 'cl'])

# %%
strength.id = conns.groupby(['pre']).mean().index
strength.avg = [means.loc[x] for x in strength.id]
strength['stds'] = [stds.loc[x] for x in strength.id]
strength.cl = [col_dict[x] for x in strength.id]
strength = strength.sort_values(by=['cl'])

# %%
strength
# Out:
#                      id        avg      stds      cl
# 0    720575940590912819   4.400000  0.244949    blue
# 155  720575940618033200   6.000000  0.640723    blue
# 156  720575940618065457  12.950820  2.570345    blue
# 445  720575940638141811  20.704225  2.051805    blue
# 162  720575940618165589  13.964912  1.064263    blue
# ..                  ...        ...       ...     ...
# 180  720575940619007664  20.192308  6.701554  yellow
# 401  720575940632368992   9.173913  0.723918  yellow
# 210  720575940620102988   8.341772  0.987735  yellow
# 209  720575940620094633   9.857143  1.079891  yellow
# 238  720575940621814054  12.134328  2.028728  yellow
#
# [477 rows x 4 columns]

# %%
fig = plt.figure()
fig.set_size_inches(10, 7)
ax = plt.axes()
ax.scatter(strength.avg, np.arange(477),  c=list(strength.cl))
ax.errorbar(strength.avg, np.arange(477),  xerr=strength.stds, zorder=0, fmt="none", marker=None)
ax.set_xlabel('strength')
ax.set_ylabel('this doesnt matter')
ax.set_title('avg connection strength per ALLN per morphological group w/ std err')
# Out:
# Text(0.5, 1.0, 'avg connection strength per ALLN per morphological group w/ std err')

# %% [markdown]
# e. Plot morphological groups in different colours in a flywire scene.

# %%
flywire.encode_url(strength.id, seg_colors = col_dict)
# Out:
# 'https://ngl.flywire.ai/?json_url=https://globalv1.flywire-daf.com/nglstate/6745983232770048'

# %% [markdown]
# f. Plot locations of synapse clouds per morphological groups of ALLNs, divided by dendritic and axonal arbors. Do specific morphological groups innervate specific areas of the AL?

# %%
blues = strength[strength.cl=='blue'].iloc[10:20].id
magentas = strength[strength.cl=='magenta'].iloc[:10].id
cyans = strength[strength.cl=='cyan'].iloc[10:20].id
greens = strength[strength.cl=='green'].iloc[10:20].id
limes = strength[strength.cl=='lime'].iloc[:10].id
oranges = strength[strength.cl=='orange'].iloc[19:29].id
purples = strength[strength.cl=='purple'].iloc[[1,4,5,7,8,12,13,14,15,16]].id
reds = strength[strength.cl=='red'].iloc[:10].id
yellows = strength[strength.cl=='yellow'].iloc[:10].id

# %%
sample_ids = np.asarray([blues, magentas, cyans, greens, limes, oranges, purples, reds, yellows]).flatten()

# %%
sample_syns = flywire.fetch_synapses(sample_ids)
# Out:
# WARNING:root:201 - "Limited query to 200000 rows

# %%
xs = sample_syns.pre_x
ys = sample_syns.pre_y
zs = sample_syns.pre_z
cols = [col_dict[sample_syns.loc[x].pre] if sample_syns.loc[x].pre in sample_ids else col_dict[sample_syns.loc[x].post] for x in sample_syns.index]

# %%
fig = plt.figure()
fig.set_size_inches(25, 25)
ax = plt.axes(projection='3d')
ax.scatter3D(xs, ys, zs, c=cols, s=1, alpha=.3)

# %% [markdown]
# YES!
